# %%
print ('hello')
# Out:
# hello

# %% [markdown]
# # 모듈 정의하기
#
# 1.calc.py 모듈만들기
# 2.모듈내에 함수 정의 - add()

# %% [markdown]
# # 모듈 가져오기
#
# import 모듈이용 as 별명
# from 함수

# %% [markdown]
# # 모듈 단독으로 실행
#
# # 터미널
# # python calc.py실행
#
# if__name__ == '__main':
# #실행을 넣어준다
# print('hi')

# %%
import calc
calc.add(10, 20)
# Out:
# 30

# %%
print(calc.add(10, 20))
# Out:
# 30

# %%
from calc import add, multiply, uuuu
print (add(2,3))
print (multiply(20,30))
print (uuuu(30,20))
# Out:
# 5
# 600
# 10

# %%
from calc import *
print (add(2,3))
print (multiply(20,30))
print (uuuu(30,20))
# Out:
# 5
# 600
# 10

# %%
import calc as cc
print(cc.add(10,5))
# Out:
# 15

# %%
import math
print(math.sqrt(64))
# Out:
# 8.0

# %%
import random
print (random. randint(1,100))
# Out:
# 3

# %%
import datetime
print ( datetime.datetime.now())
# Out:
# 2026-08-10 10:47:51.323733

# %%
import os
print (os.getcwd())
# Out:
# c:\study\python-basic

# %%
import sys
print (sys.version)
# Out:
# 3.13.15 (tags/v3.13.15:4061bc4, Aug  5 2026, 13:05:39) [MSC v.1944 64 bit (AMD64)]

# %%
import time
print ( time.sleep(12))
# Out:
# None

# %% [markdown]
# # 라이브러리 가져오기
# 1. pip install
# 2,import 라이브러리

# %%
import requests

# %%
requests.get("https://www.google.com")
# Out:
# <Response [200]>

# %%
import requests

# %% [markdown]
# # 판다스 설치

# %%
import pandas as pd

df = pd.DataFrame({
    "이름": ["홍길동", "김철수"],
    "나이": [20, 25]
})

print(df)
# Out:
#     이름  나이
# 0  홍길동  20
# 1  김철수  25

# %%
#라이브러리 호출
import pandas as pd

# 표로 보기위한 원시 데이터(딕셔너리)
data = {
    '이름': ['김철수', '이영희', '박민수', '정수진', '최영호', '한미래', '윤지원'],
    '나이': [25, 28, 22, 31, 27, 24, 29],
    '점수': [85, 92, 78, 95, 88, 73, 91]
}
df = pd.DataFrame(data)
df
# Out:
#     이름  나이  점수
# 0  김철수  25  85
# 1  이영희  28  92
# 2  박민수  22  78
# 3  정수진  31  95
# 4  최영호  27  88
# 5  한미래  24  73
# 6  윤지원  29  91

# %%
#판다스의 데이터프레임객체 생성
df = pd.DataFrame(data)
#상위 5개의 데이터 조회
df

# %%
#df의 나이 속성의 평균을 구하세요
int(df["나이"].mean())
# Out:
# 26

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     이름  나이  점수
# 0  김철수  25  85
# 1  이영희  28  92
# 2  박민수  22  78
# 3  정수진  31  95
# 4  최영호  27  88
# 5  한미래  24  73
# 6  윤지원  29  91>

# %% [markdown]
# # 패키지
#
# 모듈의 집합> 디렉토리(폴더)로 묶어준다
#
# C:\study\python-basic\my_first_pakage

# %% [markdown]
# 모듈을 호출하는 코드 :  C:\study\python-basic\my_first_pakage\main_app.py
# 모듈은 패키지 magic_calc에 포함:
# C:\study\python-basic\my_first_pakage\magic_calc\basic_ops.py
# C:\study\python-basic\my_first_pakage\magic_calc\basic_ops.py
