# %%
print(42)
#변수 선언
name = "강민우" #식별자
print(name)
"강민우" #문자열
# Out:
# 42
# 강민우
# '강민우'

# %%
name=="강민우"
# Out:
# True

# %%
name = input ("이름을 입력하세요")
print(name)
# Out:
# 강민우

# %%
age = int(input("나이를입력하세요:"))
print("내년나이", age+1)
# Out:
# 내년나이 33

# %%
x, y = input("두 수를 입력하세요(공백으로 구분)"). split()
x = int(x)
y = int(y)
print(" 두 수의 합 : ", x + y)
# Out:
#  두 수의 합 :  2468

# %%
input("두 수를 입력하세요(공백으로 구분)"). split()
x = int(x)
y = int(y)
print(" 두 수의 합 : ", x + y)
# Out:
#  두 수의 합 :  52

# %%
이름 = "강민우"
나이 = 20
print(f"안녕하세요 제이름은 {이름}이고 나이는 {나이}입니다.")
# Out:
# 안녕하세요 제이름은 강민우이고 나이는 20입니다.

# %%
number1 = 100
number2 = "100"

# %%
type(number1) , type(number2)
# Out:
# (int, str)

# %%
print(f'number1의 데이터 타입은{type(number1)} 이고, numbe2의 데이터 타입은 {type(number2)} 입니다."')
# Out:
# number1의 데이터 타입은<class 'int'> 이고, numbe2의 데이터 타입은 <class 'str'> 입니다."

# %%
age = int(input("나이를 입력하세요: "))
print("내년 나이 :" , age+1)
# Out:
# 내년 나이 : 656

# %%
num1 = 30
num2 = 40
hap = num1 + num2
print(hap, num1)
# Out:
# 70 30

# %%
text1 = "hello, python"
text2 = "안녕하세요"

# %%
text = " i'm learning pyhton"
quote = ' he said, "Python is great!"'

# %%
text1 + text2, #text1*text2
# Out:
# ('hello, python안녕하세요',)

# %%
text[1],text[-1], text[13]
# Out:
# ('i', 'n', 'g')

# %%
text[0:10:2]
# Out:
# " ' er"

# %%
text = "Python"

# %%
print(text+ "is fun!")
print("Hello!" *3)
# Out:
# Pythonis fun!
# Hello!Hello!Hello!

# %%
print(text[0:3])
print(text[2:])
print(text[:4])
print(text[-3:])
print(text[::2])
# Out:
# Pyt
# thon
# Pyth
# hon
# Pto

# %%
text = " Python Programming "

# %%
print(text.strip())
print(text.upper())
print(text.replace("Python", "Java"))
print(text.lower())
# Out:
# Python Programming
#  PYTHON PROGRAMMING
#  Java Programming
#  python programming

# %%
fruits = ["사과", "바나나", "포도"]
numbers = [1, 2, 3, 4, 5]
mixed = [10, "Python", 3.14, True]

# %%
type(fruits)
# Out:
# list

# %%
fruits[0]
# Out:
# '사과'

# %%
type(fruits[0])
# Out:
# str

# %%
fruits[0] = 'apple'

# %%
fruits
# Out:
# ['apple', '바나나', '포도']

# %%
numbers[1]= 100
print(numbers)

matrix = [[1,2] , [3, 4]]
print(matrix)
# Out:
# [1, 100, 3, 4, 5]
# [[1, 2], [3, 4]]

# %%
matrix[0][0]
# Out:
# 1

# %%
list1 = [ 1, 2, 3]
list2 = [4, 5, 6]
print(list1 + list2)
print (list1 * 2)
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 1, 2, 3]

# %%
list1 = [1, 2, 3]
list2 = [1, 2, 3]
list3 = list1

print(list1 is list2)
print(list1 == list2)
print(list1 is list3)
# Out:
# False
# True
# True

# %% [markdown]
# ## 리스트, 셋, 딕셔너리
# # 자료구조입니다

# %% [markdown]
# # 연습문제

# %%
snack_box = ['초코파이']
snack_box
# Out:
# ['초코파이']

# %%
snack_box = ['초코파이']
new_snack = input('먹고싶은 간식을 입력하세요: (, 로 여러개를 입력하세요' ).split(',')
snack_box += new_snack
snack_box
# Out:
# ['초코파이', '마이구미', ' 청포도사탕']

# %%
#몇상자 주문하시겠어요? 숫자로

box_count = int(input("몇 상자를 주문하시겠어요? : 숫자로 입력하세요"))

# %%
#빼고싶은 간식이 있으면 번호를 입력하세요

# %%
int(input("빼고 싶은 간식이 있으면 번호를 입력하세요(없으면 0): "))
# Out:
# 6

# %%
print("주문해주셔서 감사합니다!")
# Out:
# 주문해주셔서 감사합니다!

# %%
snack_box = ['초코파이']
new_snack = input('먹고싶은 간식을 입력하세요: (, 로 여러개를 입력하세요' ).split(',')
snack_box += new_snack
snack_box
# Out:
# ['초코파이', '하리보', ' 몽쉘', ' 마이구미']

# %%
new_snack = input('먹고 싶은 간식을 입력하세요(,로 여러 개 입력): ').split(',')
snack_box += new_snack
box_count = int(input("몇 상자를 주문하시겠어요? : 숫자로 입력하세요"))

# %% [markdown]
# # 프로그램의 순차구조
# 1. 순차 구조
# 2. 조건 구조 : if 문, if - else , if -elif - else
# 3.반복 구조 :
# 1) for - range(), list, str
# 2)

# %% [markdown]
# # 조건식

# %%
age = int(input('나이를 입력하세요'))
if age>= 20 :
    print('환영합니다')
    print('여러분!!')
else:
    print('돌아가세요')
    print('여러분')
# Out:
# 환영합니다
# 여러분!!

# %%
num = int(input("숫자를 입력하세요 : "))

if num % 2 == 1 :
    print("홀수입니다.")
else:
    print("짝수입니다.")
# Out:
# 짝수입니다.

# %%
score = 90
if score >80 :
    print('pass')
else :
    print('fail')
# Out:
# pass

# %%
score = 90
if score >80 : print('pass')
else : print('fail')
# Out:
# pass

# %%
score = 90
print('pass') if score >95 else print('fail')
# Out:
# fail

# %% [markdown]
# # elif 해보기
#
# 167

# %%
score = 60

if score >= 90:
        print("A 학점입니다")
elif score >= 80:
        print("B 학점입니다.")
elif score >= 70:
        print ("C 학점입니다.")
else : 
        print("F 학점입니다")
# Out:
# F 학점입니다

# %% [markdown]
# # for

# %%
#시퀀스
fruits = [ "사과", "바나나", "복숭아"]

for fruit in fruits :
    print( fruits)
# Out:
# ['사과', '바나나', '복숭아']
# ['사과', '바나나', '복숭아']
# ['사과', '바나나', '복숭아']

# %%
#문자열도 시퀀스,인덱스

hi = ['hello']
for f in hi :
    print(f)
# Out:
# hello

# %%
range(3)
# Out:
# range(0, 3)

# %%
for x in range(5):
    print(x)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
user_input = '?'
while user_input != 'exit':
    user_input = input('원하는 과자를 입려하세요. 끝내시려면 "exit"를 입력합니다')
    print(user_input)
# Out:
# 과자
# 과자2
# 과자3
# exit

# %%
def add(a,b):
    return a+b

print(add(2,3))
# Out:
# 5

# %%
import random

dice_number = random.randint (1, 80)
print(f"주사위 결과:{dice_number} ")
# Out:
# 주사위 결과:53

# %% [markdown]
# # 함수
#
# function 함수
# method 함수
